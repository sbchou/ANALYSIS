# %%
import beauty
from textstat.textstat import textstat
import csv
import pandas
import matplotlib
import matplotlib.pyplot as plt
#matplotlib.style.use('ggplot')
# %matplotlib inline
beauty.set_tex(False)

# %%
group_A = pandas.DataFrame.from_csv('DATA/demographics_A.csv')
group_B = pandas.DataFrame.from_csv('DATA/demographics_B.csv')
group_AB = pandas.concat([group_A, group_B])

# %%
group_A.columns
group_B.columns
# Out:
# Index([u'_country', u'_region', u'_city',
#        u'if_the_election_were_tomorrow_i_would_vote_for', u'what_is_your_age',
#        u'what_is_your_gender', u'what_is_your_political_party_affiliation'],
#       dtype='object')

# %% [markdown]
# ## Demographics (Gender, Age, Location)

# %%
group_A['what_is_your_gender'].value_counts().plot.pie(label="", autopct='%1.1f%%', fontsize=20, figsize=(6, 6))
plt.ylabel('Gender Breakdown for Group A', fontsize=20)
plt.savefig('FIGS/gender_A.png')
plt.show()

group_B['what_is_your_gender'].value_counts().plot.pie(label="", autopct='%1.1f%%', fontsize=20, figsize=(6, 6))
plt.ylabel('Gender Breakdown for Group B', fontsize=20)
plt.savefig('FIGS/gender_B.png')
plt.show()

# %%
group_A[['_city','_region']].to_csv('DATA/locations_A.csv')
group_B[['_city','_region']].to_csv('DATA/locations_B.csv')

# %%
group_A['_region'].value_counts().plot(kind='bar',fontsize=3)
plt.title('Participants by State Group A',fontsize=5)
plt.savefig('FIGS/state_A.png')
plt.show()

group_B['_region'].value_counts().plot(kind='bar',fontsize=3)
plt.title('Participants by State Group B',fontsize=5)
plt.savefig('FIGS/state_B.png')
plt.show()

# %%
#AGE GROUP
age_to_pretty = {1829:'18-29', 3049:'30-49', 5064:'50-64',64:'64+'}
group_A.age_group = group_A.what_is_your_age.apply(lambda row: age_to_pretty[row])
group_B.age_group = group_B.what_is_your_age.apply(lambda row: age_to_pretty[row])

group_A.age_group.value_counts().plot(kind='bar',fontsize=7)
plt.title('Age Groups, Group A', fontsize=7)
plt.tight_layout()
plt.savefig('FIGS/ages_A.png')
plt.show()

group_B.age_group.value_counts().plot(kind='bar',fontsize=7)
plt.title('Age Groups, Group B', fontsize=7)
plt.tight_layout()
plt.savefig('FIGS/ages_B.png')
plt.show()

# %%
beauty.set_tex=False
group_A.what_is_your_political_party_affiliation.value_counts().plot(kind='bar', fontsize=6)
plt.tight_layout()
plt.savefig('FIGS/party_A.png')
plt.show()

group_B.what_is_your_political_party_affiliation.value_counts().plot(kind='bar', fontsize=6)
plt.tight_layout()
plt.savefig('FIGS/party_B.png')
plt.show()

# %% [markdown]
# ## Who are you voting for?
# ## and by location, age, gender

# %%
print group_A.if_the_election_were_tomorrow_i_would_vote_for.value_counts().to_string()
print 
print group_B.if_the_election_were_tomorrow_i_would_vote_for.value_counts().to_string()
# Out:
# hillary_clinton    20
# bernie_sanders     18
# donald_trump       12
# ted_cruz            9
# might_not_vote      7
# john_kasich         3
# other               3
#
# bernie_sanders     19
# hillary_clinton    18
# donald_trump       15
# might_not_vote      6
# john_kasich         5
# ted_cruz            5
# other               4

# %%
group_A.if_the_election_were_tomorrow_i_would_vote_for.value_counts().plot(kind='bar', fontsize=5)
plt.title('Preferred Candidate, Group A', fontsize=7)
plt.savefig('FIGS/voting_for_A.png')
plt.show()

group_B.if_the_election_were_tomorrow_i_would_vote_for.value_counts().plot(kind='bar', fontsize=5)
plt.title('Preferred Candidate, Group B', fontsize=7)
plt.savefig('FIGS/voting_for_B.png')
plt.show()

# %% [markdown]
# ## Preferred Candidate by Gender

# %%
group_A[group_A.what_is_your_gender=='female'].if_the_election_were_tomorrow_i_would_vote_for.value_counts().plot(kind='bar', fontsize=5)
plt.title('Preferred Candidate, Female, Group A', fontsize=7)
plt.savefig('FIGS/voting_for_A_female.png')
plt.show()

group_A[group_A.what_is_your_gender=='male'].if_the_election_were_tomorrow_i_would_vote_for.value_counts().plot(kind='bar', fontsize=5)
plt.title('Preferred Candidate, Male, Group A', fontsize=7)
plt.savefig('FIGS/voting_for_A_male.png')
plt.show()

group_B[group_B.what_is_your_gender=='female'].if_the_election_were_tomorrow_i_would_vote_for.value_counts().plot(kind='bar', fontsize=5)
plt.title('Preferred Candidate, Female, Group B', fontsize=7)
plt.savefig('FIGS/voting_for_B_female.png')
#plt.savefig('FIGS/voting_for_A.png')
plt.show()

group_B[group_B.what_is_your_gender=='male'].if_the_election_were_tomorrow_i_would_vote_for.value_counts().plot(kind='bar', fontsize=5)
plt.title('Preferred Candidate, Male, Group B', fontsize=7)
plt.savefig('FIGS/voting_for_B_male.png')
plt.show()

group_AB[group_AB.what_is_your_gender=='female'].if_the_election_were_tomorrow_i_would_vote_for.value_counts().plot(kind='bar', fontsize=5)
plt.title('Preferred Candidate, Female, All', fontsize=7)
plt.savefig('FIGS/voting_for_AB_female.png')
plt.show()

group_AB[group_AB.what_is_your_gender=='male'].if_the_election_were_tomorrow_i_would_vote_for.value_counts().plot(kind='bar', fontsize=5)
plt.title('Preferred Candidate, Male, All', fontsize=7)
plt.savefig('FIGS/voting_for_AB_male.png')
plt.show()
